# %%
from meteostat import Stations, Monthly
from datetime import datetime
from sqlalchemy import create_engine, Column, String, Float, Integer, Date, ForeignKey
from sqlalchemy.orm import sessionmaker, declarative_base, relationship
import pandas as pd
from tqdm.notebook import tqdm
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

# %%
DATABASE_URL = "sqlite:///weather_data.db"
Base = declarative_base()
engine = create_engine(DATABASE_URL)
Session = sessionmaker(bind=engine)
session = Session()

# %%
class Station(Base):
    __tablename__ = 'stations'

    id = Column(String, primary_key=True)
    name = Column(String)
    country = Column(String)
    region = Column(String, nullable=True)
    city = Column(String, nullable=True)
    latitude = Column(Float)
    longitude = Column(Float)
    elevation = Column(Float)
    timezone = Column(String)
    daily_start = Column(Date)
    daily_end = Column(Date)
    monthly_start = Column(Date)
    monthly_end = Column(Date)

    weather_data = relationship("Weather", back_populates="station")

class Weather(Base):
    __tablename__ = 'weather'

    id = Column(Integer, primary_key=True, autoincrement=True)
    station_id = Column(String, ForeignKey('stations.id'))
    date = Column(Date)
    temperature_avg = Column(Float, nullable=True)
    temperature_min = Column(Float, nullable=True)
    temperature_max = Column(Float, nullable=True)
    precipitation = Column(Float, nullable=True)
    # snow_depth = Column(Float, nullable=True)
    # wind_dir = Column(Float, nullable=True)
    wind_speed = Column(Float, nullable=True)
    # wind_gust = Column(Float, nullable=True)
    pressure = Column(Float, nullable=True)
    sunshine = Column(Float, nullable=True)

    station = relationship("Station", back_populates="weather_data")

Base.metadata.create_all(engine)

# %%
stations = Stations().fetch()

# %%
stations
# Out:
#                                     name country region    wmo  icao  \
# id
# 00FAY                        Holden Agdm      CA     AB  71227  CXHD
# 00TG6                        Athabasca 1      CA     AB   <NA>  <NA>
# 01001                          Jan Mayen      NO   <NA>  01001  ENJA
# 01002                           Grahuken      NO     SJ  01002  <NA>
# 01003                           Hornsund      NO   <NA>  01003  <NA>
# ...                                  ...     ...    ...    ...   ...
# ZXYDC                          Bonavista      CA     NL  71178  <NA>
# ZYC17                   Kingston Airport      CA     ON   <NA>  <NA>
# ZYITU  Selfridge Air National Guard Base      US     MI   <NA>  KMTC
# ZYTX0      Shenyang / Fengt'ien / Mukden      CN     LN   <NA>  ZYTX
# ZZQV1                 Poppenburg (pegel)      DE     NI   <NA>  <NA>
#
#        latitude  longitude  elevation          timezone hourly_start  \
# id
# 00FAY   53.1900  -112.2500      688.0  America/Edmonton   2020-01-01
# 00TG6   54.7200  -113.2900      515.0  America/Edmonton          NaT
# 01001   70.9333    -8.6667       10.0       Europe/Oslo   1931-01-01
# 01002   79.7833    14.4667        0.0       Europe/Oslo   1986-11-09
# 01003   77.0000    15.5000       10.0       Europe/Oslo   1985-06-01
# ...         ...        ...        ...               ...          ...
# ZXYDC   48.6700   -53.1100       26.0  America/St_Johns   2020-01-01
# ZYC17   44.2300   -76.6000       92.0   America/Toronto   2020-01-01
# ZYITU   42.6046   -82.8353      177.0   America/Detroit   2022-04-23
# ZYTX0   41.8000   123.4000       35.0     Asia/Shanghai   1992-07-01
# ZZQV1   52.1356     9.7620       75.0     Europe/Berlin   2023-05-08
#
#       hourly_end daily_start  daily_end monthly_start monthly_end
# id
# 00FAY 2024-12-07  2002-11-01 2024-03-13    2003-01-01  2022-01-01
# 00TG6        NaT  2000-01-01 2022-07-12    2000-01-01  2010-01-01
# 01001 2025-03-20  1921-12-31 2025-04-04    1922-01-01  2022-01-01
# 01002 2025-03-20  2010-10-07 2020-08-17           NaT         NaT
# 01003 2025-03-20  2009-11-26 2020-08-31    2016-01-01  2017-01-01
# ...          ...         ...        ...           ...         ...
# ZXYDC 2022-12-14  2006-07-09 2022-12-11    2006-01-01  2022-01-01
# ZYC17 2022-12-15  2018-10-29 2022-12-12    2019-01-01  2022-01-01
# ZYITU 2025-04-07  2022-04-24 2022-04-25           NaT         NaT
# ZYTX0 2025-04-07  1994-03-07 2022-04-25    2006-01-01  2022-01-01
# ZZQV1 2025-03-24         NaT        NaT           NaT         NaT
#
# [15922 rows x 15 columns]

# %%
stations = stations.drop(columns=['wmo', 'icao', 'hourly_start', 'hourly_end'])
stations = stations.dropna()
stations
# Out:
#                                 name country region  latitude  longitude  \
# id
# 00FAY                    Holden Agdm      CA     AB   53.1900  -112.2500
# 00TG6                    Athabasca 1      CA     AB   54.7200  -113.2900
# 01004                 New Alesund II      NO     SJ   78.9167    11.9333
# 01007                    New Alesund      NO     SJ   78.9167    11.9333
# 01015           Hekkingen Lighthouse      NO     TR   69.6000    17.8333
# ...                              ...     ...    ...       ...        ...
# ZWWW0       Diwopu / Urumqi /  Dihua      CN     XJ   43.9000    87.4667
# ZX07Q                        Okotoks      CA     AB   50.7300  -113.9600
# ZXYDC                      Bonavista      CA     NL   48.6700   -53.1100
# ZYC17               Kingston Airport      CA     ON   44.2300   -76.6000
# ZYTX0  Shenyang / Fengt'ien / Mukden      CN     LN   41.8000   123.4000
#
#        elevation          timezone daily_start  daily_end monthly_start  \
# id
# 00FAY      688.0  America/Edmonton  2002-11-01 2024-03-13    2003-01-01
# 00TG6      515.0  America/Edmonton  2000-01-01 2022-07-12    2000-01-01
# 01004        8.0       Europe/Oslo  1968-12-31 1997-03-01    1969-01-01
# 01007        0.0       Europe/Oslo  1973-03-28 2025-04-04    1974-01-01
# 01015       14.0       Europe/Oslo  1979-10-31 2021-09-06    1979-01-01
# ...          ...               ...         ...        ...           ...
# ZWWW0      654.0       Asia/Urumqi  1990-08-27 2022-04-25    2006-01-01
# ZX07Q     1081.0  America/Edmonton  2000-01-01 2022-12-02    2000-01-01
# ZXYDC       26.0  America/St_Johns  2006-07-09 2022-12-11    2006-01-01
# ZYC17       92.0   America/Toronto  2018-10-29 2022-12-12    2019-01-01
# ZYTX0       35.0     Asia/Shanghai  1994-03-07 2022-04-25    2006-01-01
#
#       monthly_end
# id
# 00FAY  2022-01-01
# 00TG6  2010-01-01
# 01004  1974-01-01
# 01007  2022-01-01
# 01015  2021-01-01
# ...           ...
# ZWWW0  2022-01-01
# ZX07Q  2021-01-01
# ZXYDC  2022-01-01
# ZYC17  2022-01-01
# ZYTX0  2022-01-01
#
# [12000 rows x 11 columns]

# %%
geolocator = Nominatim(user_agent='weather_app')

def get_nearest_city(lat, lon):
    try:
        location = geolocator.reverse((lat, lon), exactly_one=True, timeout=10)
        if location:
            address = location.raw.get('address', {})
            city_name = address.get('city') or address.get('town') or address.get('village') or None
            print(city_name)
            return city_name
    except GeocoderTimedOut:
        print('Request time out')
        return None
    except Exception as e:
        print(e)
        return None

# tqdm.pandas()
# stations['city'] = stations.progress_apply(
#     lambda row: get_nearest_city(row['latitude'], row['longitude']) if row['country'] == 'RU' else None, axis=1
# )

# %%
for _, station in stations.iterrows():
    station_entry = Station(
        id=station.name,
        name=station['name'],
        country=station['country'],
        region=station['region'],
        # city=station['city'],
        latitude=station['latitude'],
        longitude=station['longitude'],
        elevation=station['elevation'],
        timezone=station['timezone'],
        daily_start=station['daily_start'],
        daily_end=station['daily_end'],
        monthly_start=station['monthly_start'],
        monthly_end=station['monthly_end']
    )
    session.add(station_entry)
session.commit()

# %%
ru_stations = stations[stations.country == 'RU']
ru_stations
# Out:
#                                name country region  latitude  longitude  \
# id
# 20046  Polargmo Im. E. T. Krenkelja      RU    ARK   80.6167    58.0500
# 20049                   Tikhaya Bay      RU    NEN   80.3667    52.9167
# 20069                   Ostrov Vize      RU    TAY   79.5000    76.9833
# 20087            Ostrov Golomjannyj      RU     KY   79.5500    90.6167
# 20274             Ostrov Uedinenija      RU    TAY   77.5000    82.2000
# ...                             ...     ...    ...       ...        ...
# UWKS0         Cheboksary / Sin’yaly      RU     CU   56.0833    47.3500
# UWLL0       Ulyanovsk / Baratayevka      RU    ULY   54.2667    48.2167
# UWLW0         Ulyanovsk / Loshchina      RU    ULY   54.4000    48.8000
# UWOO0     Trudovoye Pole / Orenberg      RU    ORE   51.7833    55.4500
# UWUU0     Ufa / Lokotki / Peschanyy      RU     BA   54.5500    55.8667
#
#        elevation            timezone daily_start  daily_end monthly_start  \
# id
# 20046       20.0       Europe/Moscow  1957-12-02 2025-03-06    1958-01-01
# 20049       46.0       Europe/Moscow  1966-01-01 1995-04-30    1966-01-01
# 20069       10.0           Asia/Omsk  1945-11-01 2025-03-06    1945-01-01
# 20087        8.0    Asia/Krasnoyarsk  1936-04-01 2025-03-06    1936-01-01
# 20274       23.0    Asia/Novosibirsk  1936-01-01 1996-11-21    1936-01-01
# ...          ...                 ...         ...        ...           ...
# UWKS0      170.0       Europe/Moscow  2008-10-28 2022-04-25    2017-01-01
# UWLL0      141.0    Europe/Volgograd  2005-01-15 2022-04-25    2006-01-01
# UWLW0       77.0    Europe/Volgograd  2004-07-15 2022-04-24    2013-01-01
# UWOO0      118.0  Asia/Yekaterinburg  1998-02-16 2022-04-25    2006-01-01
# UWUU0      125.0  Asia/Yekaterinburg  1999-08-15 2022-04-25    2006-01-01
#
#       monthly_end
# id
# 20046  2021-01-01
# 20049  1995-01-01
# 20069  2021-01-01
# 20087  2021-01-01
# 20274  1996-01-01
# ...           ...
# UWKS0  2022-01-01
# UWLL0  2022-01-01
# UWLW0  2022-01-01
# UWOO0  2022-01-01
# UWUU0  2022-01-01
#
# [1181 rows x 11 columns]

# %%
continent_df = pd.read_csv('country-and-continent-codes-list-csv.csv')

european_countries = set(
    continent_df[
        (continent_df['Continent_Name'] == 'Europe') &
        (continent_df['Country_Name'] != 'Russian Federation')
    ]['Two_Letter_Country_Code'].str.upper()
)

europe_stations = stations[stations['country'].isin(european_countries)]
europe_stations
# Out:
#                                              name country region  latitude  \
# id
# 01004                              New Alesund II      NO     SJ   78.9167
# 01007                                 New Alesund      NO     SJ   78.9167
# 01015                        Hekkingen Lighthouse      NO     TR   69.6000
# 01025                              Tromso Airport      NO     TR   69.6833
# 01026                                      Tromso      NO     TR   69.6500
# ...                                           ...     ...    ...       ...
# UKCW0                Lugansk / Luhans'k / Shmidta      UA     LH   48.4167
# UKDD0  Dnepropetrovsk / Dnipropetrovs'k / Kaydaki      UA     DP   48.3500
# UKKM0                     Kiev / Kyiv / Yablon’ki      UA     KV   50.6000
# UKLI0                Ivano-Frankovsk / Chukaluvka      UA     IF   48.8833
# UKWW0          Vinnitsa / Vinnytsia / Gavrishëvka      UA     VI   49.2333
#
#        longitude  elevation           timezone daily_start  daily_end  \
# id
# 01004    11.9333        8.0        Europe/Oslo  1968-12-31 1997-03-01
# 01007    11.9333        0.0        Europe/Oslo  1973-03-28 2025-04-04
# 01015    17.8333       14.0        Europe/Oslo  1979-10-31 2021-09-06
# 01025    18.9167        1.0        Europe/Oslo  1964-09-30 2024-01-04
# 01026    18.9333      103.0        Europe/Oslo  1920-07-01 2025-04-04
# ...          ...        ...                ...         ...        ...
# UKCW0    39.3667      194.0  Europe/Zaporozhye  2004-05-11 2014-06-07
# UKDD0    35.1000      146.0  Europe/Zaporozhye  2004-05-11 2022-02-23
# UKKM0    30.2000      161.0        Europe/Kiev  2004-07-15 2022-02-24
# UKLI0    24.6833      280.0    Europe/Uzhgorod  2020-01-15 2022-02-23
# UKWW0    28.6000      297.0        Europe/Kiev  2020-01-15 2022-01-27
#
#       monthly_start monthly_end
# id
# 01004    1969-01-01  1974-01-01
# 01007    1974-01-01  2022-01-01
# 01015    1979-01-01  2021-01-01
# 01025    1964-01-01  2022-01-01
# 01026    1920-01-01  2022-01-01
# ...             ...         ...
# UKCW0    2013-01-01  2014-01-01
# UKDD0    2012-01-01  2022-01-01
# UKKM0    2007-01-01  2022-01-01
# UKLI0    2020-01-01  2022-01-01
# UKWW0    2020-01-01  2021-01-01
#
# [3049 rows x 11 columns]

# %%
import warnings
from sqlalchemy.exc import IntegrityError
from requests.exceptions import ConnectionError, RequestException
from urllib3.exceptions import ProtocolError
warnings.filterwarnings('ignore')
session.rollback()
i = 1
total = len(europe_stations)
print(f'Total {total} stations')
for _, station in europe_stations.iterrows():
    try:
        # Skip if station data already exists
        exists = session.query(Weather).filter_by(station_id=station.name).first()
        if exists:
            print(f"Skipping station {station.name} - data already exists")
            i += 1
            continue

        start = station['monthly_start'].to_pydatetime()
        end = station['monthly_end'].to_pydatetime()

        # Fetch data with error handling
        try:
            data_m = Monthly(station.name, start, end)
            data = data_m.fetch()
        except (ConnectionError, ConnectionResetError, ProtocolError, RequestException) as e:
            print(f"Network error for station {station.name}: {str(e)} - skipping")
            continue
        except Exception as e:
            print(f"Error fetching data for station {station.name}: {str(e)} - skipping")
            continue

        # Process data
        for _, data_row in data.iterrows():
            try:
                station_entry = Weather(
                    station_id=station.name,
                    date=data_row.name,
                    temperature_avg=data_row['tavg'],
                    temperature_min=data_row['tmin'],
                    temperature_max=data_row['tmax'],
                    precipitation=data_row['prcp'],
                    wind_speed=data_row['wspd'],
                    pressure=data_row['pres'],
                    sunshine=data_row['tsun']
                )
                session.add(station_entry)
            except Exception as e:
                print(f"Error processing record {data_row.name} for station {station.name}: {str(e)}")
                session.rollback()
                continue

        session.commit()

    except IntegrityError:
        session.rollback()
        print(f"Integrity error for station {station.name} - likely duplicate, skipping")
    except Exception as e:
        session.rollback()
        print(f"Unexpected error processing station {station.name}: {str(e)} - skipping")
    finally:
        if i % 50 == 0:
            print(f"Processed {i} stations")
        i += 1

print("Completed processing European stations")
# Out:
# Total 3049 stations
# Skipping station 01004 - data already exists
# Skipping station 01007 - data already exists
# Skipping station 01015 - data already exists
# Skipping station 01025 - data already exists
# Skipping station 01026 - data already exists
# Skipping station 01027 - data already exists
# Skipping station 01028 - data already exists
# Skipping station 01033 - data already exists
# Skipping station 01037 - data already exists
# Skipping station 01046 - data already exists
# Skipping station 01049 - data already exists
# Skipping station 01051 - data already exists
# Skipping station 01055 - data already exists
# Skipping station 01058 - data already exists
# Skipping station 01059 - data already exists
# Skipping station 01065 - data already exists
# Skipping station 01068 - data already exists
# Skipping station 01074 - data already exists
# Skipping station 01078 - data already exists
# Skipping station 01083 - data already exists
# Skipping station 01092 - data already exists
# Skipping station 01097 - data already exists
# Skipping station 01098 - data already exists
# Skipping station 01102 - data already exists
# Skipping station 01105 - data already exists
# Skipping station 01108 - data already exists
# Skipping station 01114 - data already exists
# Skipping station 01116 - data already exists
# Skipping station 01117 - data already exists
# Skipping station 01124 - data already exists
# Skipping station 01132 - data already exists
# Skipping station 01133 - data already exists
# Skipping station 01135 - data already exists
# Skipping station 01144 - data already exists
# Skipping station 01148 - data already exists
# Skipping station 01150 - data already exists
# Skipping station 01152 - data already exists
# Skipping station 01156 - data already exists
# Skipping station 01158 - data already exists
# Skipping station 01160 - data already exists
# Skipping station 01161 - data already exists
# Skipping station 01162 - data already exists
# Skipping station 01180 - data already exists
# Skipping station 01192 - data already exists
# Skipping station 01194 - data already exists
# Skipping station 01205 - data already exists
# Skipping station 01210 - data already exists
# Skipping station 01212 - data already exists
# Skipping station 01217 - data already exists
# Processed 100 stations
# Skipping station 01218 - data already exists
# Skipping station 01228 - data already exists
# Skipping station 01230 - data already exists
# Skipping station 01233 - data already exists
# Skipping station 01234 - data already exists
# Skipping station 01238 - data already exists
# Skipping station 01239 - data already exists
# Skipping station 01240 - data already exists
# Skipping station 01241 - data already exists
# Skipping station 01242 - data already exists
# Skipping station 01250 - data already exists
# Skipping station 01253 - data already exists
# Skipping station 01254 - data already exists
# Skipping station 01257 - data already exists
# Skipping station 01259 - data already exists
# Skipping station 01270 - data already exists
# Skipping station 01271 - data already exists
# Skipping station 01272 - data already exists
# Skipping station 01273 - data already exists
# Skipping station 01274 - data already exists
# Skipping station 01281 - data already exists
# Skipping station 01282 - data already exists
# Skipping station 01287 - data already exists
# Skipping station 01289 - data already exists
# Skipping station 01290 - data already exists
# Processed 150 stations
# Skipping station 01291 - data already exists
# Skipping station 01293 - data already exists
# Skipping station 01304 - data already exists
# Skipping station 01308 - data already exists
# Skipping station 01310 - data already exists
# Skipping station 01314 - data already exists
# Skipping station 01315 - data already exists
# Skipping station 01317 - data already exists
# Skipping station 01319 - data already exists
# Skipping station 01326 - data already exists
# Skipping station 01327 - data already exists
# Skipping station 01329 - data already exists
# Skipping station 01332 - data already exists
# Skipping station 01340 - data already exists
# Skipping station 01342 - data already exists
# Skipping station 01346 - data already exists
# Skipping station 01347 - data already exists
# Skipping station 01352 - data already exists
# Skipping station 01358 - data already exists
# Skipping station 01361 - data already exists
# Skipping station 01362 - data already exists
# Skipping station 01365 - data already exists
# Skipping station 01366 - data already exists
# Skipping station 01367 - data already exists
# Skipping station 01368 - data already exists
# Processed 200 stations
# Skipping station 01371 - data already exists
# Skipping station 01373 - data already exists
# Skipping station 01374 - data already exists
# Skipping station 01380 - data already exists
# Skipping station 01381 - data already exists
# Skipping station 01382 - data already exists
# Skipping station 01385 - data already exists
# Skipping station 01386 - data already exists
# Skipping station 01392 - data already exists
# Skipping station 01393 - data already exists
# Skipping station 01403 - data already exists
# Skipping station 01408 - data already exists
# Skipping station 01411 - data already exists
# Skipping station 01413 - data already exists
# Skipping station 01414 - data already exists
# Skipping station 01416 - data already exists
# Skipping station 01418 - data already exists
# Skipping station 01419 - data already exists
# Skipping station 01422 - data already exists
# Skipping station 01424 - data already exists
# Skipping station 01427 - data already exists
# Skipping station 01430 - data already exists
# Skipping station 01431 - data already exists
# Skipping station 01436 - data already exists
# Skipping station 01444 - data already exists
# Processed 250 stations
# Skipping station 01447 - data already exists
# Skipping station 01448 - data already exists
# Skipping station 01449 - data already exists
# Skipping station 01450 - data already exists
# Skipping station 01452 - data already exists
# Skipping station 01455 - data already exists
# Skipping station 01463 - data already exists
# Skipping station 01464 - data already exists
# Skipping station 01465 - data already exists
# Skipping station 01466 - data already exists
# Skipping station 01467 - data already exists
# Skipping station 01468 - data already exists
# Skipping station 01469 - data already exists
# Skipping station 01471 - data already exists
# Skipping station 01473 - data already exists
# Skipping station 01478 - data already exists
# Skipping station 01480 - data already exists
# Skipping station 01481 - data already exists
# Skipping station 01482 - data already exists
# Skipping station 01484 - data already exists
# Skipping station 01486 - data already exists
# Skipping station 01490 - data already exists
# Skipping station 01492 - data already exists
# Skipping station 01493 - data already exists
# Skipping station 01495 - data already exists
# Processed 300 stations
# Skipping station 02000 - data already exists
# Skipping station 02044 - data already exists
# Skipping station 02049 - data already exists
# Skipping station 02080 - data already exists
# Skipping station 02120 - data already exists
# Skipping station 02128 - data already exists
# Skipping station 02154 - data already exists
# Skipping station 02186 - data already exists
# Skipping station 02196 - data already exists
# Skipping station 02197 - data already exists
# Skipping station 02226 - data already exists
# Skipping station 02259 - data already exists
# Skipping station 02267 - data already exists
# Skipping station 02286 - data already exists
# Skipping station 02287 - data already exists
# Skipping station 02288 - data already exists
# Skipping station 02293 - data already exists
# Skipping station 02366 - data already exists
# Skipping station 02376 - data already exists
# Skipping station 02404 - data already exists
# Skipping station 02410 - data already exists
# Skipping station 02416 - data already exists
# Skipping station 02418 - data already exists
# Skipping station 02433 - data already exists
# Skipping station 02435 - data already exists
# Processed 350 stations
# Skipping station 02443 - data already exists
# Skipping station 02446 - data already exists
# Skipping station 02458 - data already exists
# Skipping station 02460 - data already exists
# Skipping station 02464 - data already exists
# Skipping station 02468 - data already exists
# Skipping station 02485 - data already exists
# Skipping station 02512 - data already exists
# Skipping station 02520 - data already exists
# Skipping station 02526 - data already exists
# Skipping station 02535 - data already exists
# Skipping station 02550 - data already exists
# Skipping station 02556 - data already exists
# Skipping station 02562 - data already exists
# Skipping station 02565 - data already exists
# Skipping station 02571 - data already exists
# Skipping station 02584 - data already exists
# Skipping station 02589 - data already exists
# Skipping station 02590 - data already exists
# Skipping station 02604 - data already exists
# Skipping station 02607 - data already exists
# Skipping station 02636 - data already exists
# Skipping station 02641 - data already exists
# Skipping station 02651 - data already exists
# Skipping station 02664 - data already exists
# Processed 400 stations
# Skipping station 02672 - data already exists
# Skipping station 02701 - data already exists
# Skipping station 02705 - data already exists
# Skipping station 02714 - data already exists
# Skipping station 02717 - data already exists
# Skipping station 02719 - data already exists
# Skipping station 02721 - data already exists
# Skipping station 02722 - data already exists
# Skipping station 02726 - data already exists
# Skipping station 02738 - data already exists
# Skipping station 02739 - data already exists
# Skipping station 02741 - data already exists
# Skipping station 02743 - data already exists
# Skipping station 02745 - data already exists
# Skipping station 02747 - data already exists
# Skipping station 02751 - data already exists
# Skipping station 02752 - data already exists
# Skipping station 02755 - data already exists
# Skipping station 02757 - data already exists
# Skipping station 02761 - data already exists
# Skipping station 02778 - data already exists
# Skipping station 02780 - data already exists
# Skipping station 02781 - data already exists
# Skipping station 02790 - data already exists
# Skipping station 02794 - data already exists
# Processed 450 stations
# Skipping station 02795 - data already exists
# Skipping station 02797 - data already exists
# Skipping station 02799 - data already exists
# Skipping station 02801 - data already exists
# Skipping station 02803 - data already exists
# Skipping station 02804 - data already exists
# Skipping station 02805 - data already exists
# Skipping station 02807 - data already exists
# Skipping station 02811 - data already exists
# Skipping station 02812 - data already exists
# Skipping station 02813 - data already exists
# Skipping station 02814 - data already exists
# Skipping station 02815 - data already exists
# Skipping station 02816 - data already exists
# Skipping station 02817 - data already exists
# Skipping station 02818 - data already exists
# Skipping station 02819 - data already exists
# Skipping station 02820 - data already exists
# Skipping station 02821 - data already exists
# Skipping station 02823 - data already exists
# Skipping station 02824 - data already exists
# Skipping station 02827 - data already exists
# Skipping station 02828 - data already exists
# Skipping station 02835 - data already exists
# Skipping station 02836 - data already exists
# Processed 500 stations
# Skipping station 02844 - data already exists
# Skipping station 02845 - data already exists
# Skipping station 02847 - data already exists
# Skipping station 02849 - data already exists
# Skipping station 02851 - data already exists
# Skipping station 02864 - data already exists
# Skipping station 02866 - data already exists
# Skipping station 02868 - data already exists
# Skipping station 02869 - data already exists
# Skipping station 02872 - data already exists
# Skipping station 02873 - data already exists
# Skipping station 02874 - data already exists
# Skipping station 02875 - data already exists
# Skipping station 02876 - data already exists
# Skipping station 02880 - data already exists
# Skipping station 02889 - data already exists
# Skipping station 02897 - data already exists
# Skipping station 02907 - data already exists
# Skipping station 02910 - data already exists
# Skipping station 02920 - data already exists
# Skipping station 02964 - data already exists
# Skipping station 02967 - data already exists
# Skipping station 02976 - data already exists
# Skipping station 02979 - data already exists
# Skipping station 02980 - data already exists
# Processed 550 stations
# Skipping station 02981 - data already exists
# Skipping station 02982 - data already exists
# Skipping station 02984 - data already exists
# Skipping station 02987 - data already exists
# Skipping station 02992 - data already exists
# Skipping station 02998 - data already exists
# Skipping station 03003 - data already exists
# Skipping station 03005 - data already exists
# Skipping station 03014 - data already exists
# Skipping station 03017 - data already exists
# Skipping station 03022 - data already exists
# Skipping station 03035 - data already exists
# Skipping station 03044 - data already exists
# Skipping station 03059 - data already exists
# Skipping station 03062 - data already exists
# Skipping station 03066 - data already exists
# Skipping station 03068 - data already exists
# Skipping station 03075 - data already exists
# Skipping station 03100 - data already exists
# Skipping station 03111 - data already exists
# Skipping station 03132 - data already exists
# Skipping station 03135 - data already exists
# Skipping station 03136 - data already exists
# Skipping station 03140 - data already exists
# Skipping station 03158 - data already exists
# Processed 600 stations
# Skipping station 03160 - data already exists
# Skipping station 03162 - data already exists
# Skipping station 03165 - data already exists
# Skipping station 03171 - data already exists
# Skipping station 03204 - data already exists
# Skipping station 03214 - data already exists
# Skipping station 03220 - data already exists
# Skipping station 03240 - data already exists
# Skipping station 03243 - data already exists
# Skipping station 03257 - data already exists
# Skipping station 03261 - data already exists
# Skipping station 03264 - data already exists
# Skipping station 03266 - data already exists
# Skipping station 03292 - data already exists
# Skipping station 03302 - data already exists
# Skipping station 03318 - data already exists
# Skipping station 03321 - data already exists
# Skipping station 03334 - data already exists
# Skipping station 03354 - data already exists
# Skipping station 03355 - data already exists
# Skipping station 03373 - data already exists
# Skipping station 03377 - data already exists
# Skipping station 03379 - data already exists
# Skipping station 03384 - data already exists
# Skipping station 03391 - data already exists
# Skipping station 03392 - data already exists
# Skipping station 03405 - data already exists
# Skipping station 03414 - data already exists
# Skipping station 03453 - data already exists
# Skipping station 03462 - data already exists
# Skipping station 03469 - data already exists
# Skipping station 03482 - data already exists
# Skipping station 03487 - data already exists
# Skipping station 03492 - data already exists
# Skipping station 03495 - data already exists
# Skipping station 03502 - data already exists
# Skipping station 03520 - data already exists
# Skipping station 03534 - data already exists
# Skipping station 03560 - data already exists
# Skipping station 03566 - data already exists
# Skipping station 03577 - data already exists
# Skipping station 03583 - data already exists
# Skipping station 03590 - data already exists
# Skipping station 03595 - data already exists
# Skipping station 03604 - data already exists
# Skipping station 03605 - data already exists
# Skipping station 03644 - data already exists
# Skipping station 03649 - data already exists
# Skipping station 03658 - data already exists
# Processed 700 stations
# Skipping station 03672 - data already exists
# Skipping station 03673 - data already exists
# Skipping station 03683 - data already exists
# Skipping station 03691 - data already exists
# Skipping station 03707 - data already exists
# Skipping station 03715 - data already exists
# Skipping station 03716 - data already exists
# Skipping station 03724 - data already exists
# Skipping station 03740 - data already exists
# Skipping station 03743 - data already exists
# Skipping station 03746 - data already exists
# Skipping station 03749 - data already exists
# Skipping station 03761 - data already exists
# Skipping station 03768 - data already exists
# Skipping station 03772 - data already exists
# Skipping station 03776 - data already exists
# Skipping station 03779 - data already exists
# Skipping station 03781 - data already exists
# Skipping station 03797 - data already exists
# Skipping station 03801 - data already exists
# Skipping station 03803 - data already exists
# Skipping station 03808 - data already exists
# Skipping station 03809 - data already exists
# Skipping station 03817 - data already exists
# Skipping station 03827 - data already exists
# Processed 750 stations
# Skipping station 03839 - data already exists
# Skipping station 03853 - data already exists
# Skipping station 03862 - data already exists
# Skipping station 03865 - data already exists
# Skipping station 03876 - data already exists
# Skipping station 03894 - data already exists
# Skipping station 03917 - data already exists
# Skipping station 03924 - data already exists
# Skipping station 03953 - data already exists
# Skipping station 03955 - data already exists
# Skipping station 03956 - data already exists
# Skipping station 03957 - data already exists
# Skipping station 03962 - data already exists
# Skipping station 03965 - data already exists
# Skipping station 03967 - data already exists
# Skipping station 03969 - data already exists
# Skipping station 03973 - data already exists
# Skipping station 03976 - data already exists
# Skipping station 03980 - data already exists
# Skipping station 04013 - data already exists
# Skipping station 04018 - data already exists
# Skipping station 04030 - data already exists
# Skipping station 04082 - data already exists
# Skipping station 04089 - data already exists
# Skipping station 04130 - data already exists
# Skipping station 04197 - data already exists
# Skipping station 06010 - data already exists
# Skipping station 06011 - data already exists
# Skipping station 06030 - data already exists
# Skipping station 06060 - data already exists
# Skipping station 06070 - data already exists
# Skipping station 06080 - data already exists
# Skipping station 06104 - data already exists
# Skipping station 06108 - data already exists
# Skipping station 06110 - data already exists
# Skipping station 06118 - data already exists
# Skipping station 06120 - data already exists
# Skipping station 06124 - data already exists
# Skipping station 06170 - data already exists
# Skipping station 06180 - data already exists
# Skipping station 06186 - data already exists
# Skipping station 06190 - data already exists
# Skipping station 06210 - data already exists
# Skipping station 06235 - data already exists
# Skipping station 06239 - data already exists
# Skipping station 06240 - data already exists
# Skipping station 06242 - data already exists
# Skipping station 06249 - data already exists
# Skipping station 06251 - data already exists
# Processed 850 stations
# Skipping station 06257 - data already exists
# Skipping station 06260 - data already exists
# Skipping station 06265 - data already exists
# Skipping station 06267 - data already exists
# Skipping station 06269 - data already exists
# Skipping station 06270 - data already exists
# Skipping station 06273 - data already exists
# Skipping station 06275 - data already exists
# Skipping station 06277 - data already exists
# Skipping station 06278 - data already exists
# Skipping station 06279 - data already exists
# Skipping station 06280 - data already exists
# Skipping station 06283 - data already exists
# Skipping station 06286 - data already exists
# Skipping station 06290 - data already exists
# Skipping station 06310 - data already exists
# Skipping station 06319 - data already exists
# Skipping station 06323 - data already exists
# Skipping station 06330 - data already exists
# Skipping station 06340 - data already exists
# Skipping station 06344 - data already exists
# Skipping station 06348 - data already exists
# Skipping station 06350 - data already exists
# Skipping station 06356 - data already exists
# Skipping station 06370 - data already exists
# Processed 900 stations
# Skipping station 06375 - data already exists
# Skipping station 06377 - data already exists
# Skipping station 06380 - data already exists
# Skipping station 06391 - data already exists
# Skipping station 06400 - data already exists
# Skipping station 06407 - data already exists
# Skipping station 06414 - data already exists
# Skipping station 06418 - data already exists
# Skipping station 06428 - data already exists
# Skipping station 06432 - data already exists
# Skipping station 06434 - data already exists
# Skipping station 06447 - data already exists
# Skipping station 06449 - data already exists
# Skipping station 06450 - data already exists
# Skipping station 06451 - data already exists
# Skipping station 06455 - data already exists
# Skipping station 06456 - data already exists
# Skipping station 06458 - data already exists
# Skipping station 06464 - data already exists
# Skipping station 06465 - data already exists
# Skipping station 06472 - data already exists
# Skipping station 06476 - data already exists
# Skipping station 06477 - data already exists
# Skipping station 06478 - data already exists
# Skipping station 06479 - data already exists
# Skipping station 06484 - data already exists
# Skipping station 06490 - data already exists
# Skipping station 06494 - data already exists
# Skipping station 06496 - data already exists
# Skipping station 06590 - data already exists
# Skipping station 06601 - data already exists
# Skipping station 06604 - data already exists
# Skipping station 06610 - data already exists
# Skipping station 06613 - data already exists
# Skipping station 06614 - data already exists
# Skipping station 06632 - data already exists
# Skipping station 06660 - data already exists
# Skipping station 06670 - data already exists
# Skipping station 06680 - data already exists
# Skipping station 06690 - data already exists
# Skipping station 06700 - data already exists
# Skipping station 06717 - data already exists
# Skipping station 06720 - data already exists
# Skipping station 06762 - data already exists
# Skipping station 06770 - data already exists
# Skipping station 06990 - data already exists
# Skipping station 07002 - data already exists
# Skipping station 07003 - data already exists
# Skipping station 07005 - data already exists
# Skipping station 07010 - data already exists
# Skipping station 07015 - data already exists
# Skipping station 07017 - data already exists
# Skipping station 07020 - data already exists
# Skipping station 07024 - data already exists
# Skipping station 07027 - data already exists
# Skipping station 07028 - data already exists
# Skipping station 07031 - data already exists
# Skipping station 07037 - data already exists
# Skipping station 07038 - data already exists
# Skipping station 07040 - data already exists
# Skipping station 07046 - data already exists
# Skipping station 07055 - data already exists
# Skipping station 07057 - data already exists
# Skipping station 07059 - data already exists
# Skipping station 07061 - data already exists
# Skipping station 07070 - data already exists
# Skipping station 07072 - data already exists
# Skipping station 07075 - data already exists
# Skipping station 07090 - data already exists
# Skipping station 07093 - data already exists
# Skipping station 07100 - data already exists
# Skipping station 07103 - data already exists
# Skipping station 07106 - data already exists
# Skipping station 07107 - data already exists
# Skipping station 07109 - data already exists
# Skipping station 07110 - data already exists
# Skipping station 07117 - data already exists
# Skipping station 07118 - data already exists
# Skipping station 07120 - data already exists
# Skipping station 07125 - data already exists
# Skipping station 07130 - data already exists
# Skipping station 07139 - data already exists
# Skipping station 07140 - data already exists
# Skipping station 07143 - data already exists
# Skipping station 07145 - data already exists
# Skipping station 07146 - data already exists
# Skipping station 07147 - data already exists
# Skipping station 07149 - data already exists
# Skipping station 07150 - data already exists
# Skipping station 07153 - data already exists
# Skipping station 07156 - data already exists
# Skipping station 07157 - data already exists
# Skipping station 07166 - data already exists
# Skipping station 07168 - data already exists
# Skipping station 07169 - data already exists
# Skipping station 07179 - data already exists
# Skipping station 07180 - data already exists
# Skipping station 07181 - data already exists
# Skipping station 07186 - data already exists
# Processed 1100 stations
# Skipping station 07190 - data already exists
# Skipping station 07197 - data already exists
# Skipping station 07200 - data already exists
# Skipping station 07201 - data already exists
# Skipping station 07203 - data already exists
# Skipping station 07205 - data already exists
# Skipping station 07207 - data already exists
# Skipping station 07216 - data already exists
# Skipping station 07217 - data already exists
# Skipping station 07222 - data already exists
# Skipping station 07230 - data already exists
# Skipping station 07235 - data already exists
# Skipping station 07240 - data already exists
# Skipping station 07247 - data already exists
# Skipping station 07249 - data already exists
# Skipping station 07255 - data already exists
# Skipping station 07257 - data already exists
# Skipping station 07260 - data already exists
# Skipping station 07265 - data already exists
# Skipping station 07280 - data already exists
# Skipping station 07283 - data already exists
# Skipping station 07288 - data already exists
# Skipping station 07292 - data already exists
# Skipping station 07296 - data already exists
# Skipping station 07299 - data already exists
# Processed 1150 stations
# Skipping station 07300 - data already exists
# Skipping station 07306 - data already exists
# Skipping station 07314 - data already exists
# Skipping station 07315 - data already exists
# Skipping station 07330 - data already exists
# Skipping station 07335 - data already exists
# Skipping station 07354 - data already exists
# Skipping station 07361 - data already exists
# Skipping station 07374 - data already exists
# Skipping station 07379 - data already exists
# Skipping station 07385 - data already exists
# Skipping station 07386 - data already exists
# Skipping station 07412 - data already exists
# Skipping station 07428 - data already exists
# Skipping station 07434 - data already exists
# Skipping station 07438 - data already exists
# Skipping station 07460 - data already exists
# Skipping station 07471 - data already exists
# Skipping station 07475 - data already exists
# Skipping station 07476 - data already exists
# Skipping station 07477 - data already exists
# Skipping station 07480 - data already exists
# Skipping station 07481 - data already exists
# Skipping station 07482 - data already exists
# Skipping station 07486 - data already exists
# Processed 1200 stations
# Skipping station 07487 - data already exists
# Skipping station 07491 - data already exists
# Skipping station 07497 - data already exists
# Skipping station 07500 - data already exists
# Skipping station 07502 - data already exists
# Skipping station 07503 - data already exists
# Skipping station 07510 - data already exists
# Skipping station 07524 - data already exists
# Skipping station 07530 - data already exists
# Skipping station 07535 - data already exists
# Skipping station 07540 - data already exists
# Skipping station 07549 - data already exists
# Skipping station 07552 - data already exists
# Skipping station 07554 - data already exists
# Skipping station 07555 - data already exists
# Skipping station 07558 - data already exists
# Skipping station 07560 - data already exists
# Skipping station 07563 - data already exists
# Skipping station 07570 - data already exists
# Skipping station 07577 - data already exists
# Skipping station 07579 - data already exists
# Skipping station 07586 - data already exists
# Skipping station 07588 - data already exists
# Skipping station 07591 - data already exists
# Skipping station 07600 - data already exists
# Processed 1250 stations
# Skipping station 07602 - data already exists
# Skipping station 07603 - data already exists
# Skipping station 07607 - data already exists
# Skipping station 07610 - data already exists
# Skipping station 07621 - data already exists
# Skipping station 07622 - data already exists
# Skipping station 07627 - data already exists
# Skipping station 07628 - data already exists
# Skipping station 07630 - data already exists
# Skipping station 07631 - data already exists
# Skipping station 07632 - data already exists
# Skipping station 07635 - data already exists
# Skipping station 07638 - data already exists
# Skipping station 07641 - data already exists
# Skipping station 07643 - data already exists
# Skipping station 07645 - data already exists
# Skipping station 07646 - data already exists
# Skipping station 07647 - data already exists
# Skipping station 07648 - data already exists
# Skipping station 07650 - data already exists
# Skipping station 07661 - data already exists
# Skipping station 07666 - data already exists
# Skipping station 07667 - data already exists
# Skipping station 07675 - data already exists
# Skipping station 07678 - data already exists
# Processed 1300 stations
# Skipping station 07684 - data already exists
# Skipping station 07690 - data already exists
# Skipping station 07747 - data already exists
# Skipping station 07749 - data already exists
# Skipping station 07753 - data already exists
# Skipping station 07754 - data already exists
# Skipping station 07761 - data already exists
# Skipping station 07765 - data already exists
# Skipping station 07770 - data already exists
# Skipping station 07775 - data already exists
# Skipping station 07780 - data already exists
# Skipping station 07785 - data already exists
# Skipping station 07790 - data already exists
# Skipping station 07791 - data already exists
# Skipping station 08000 - data already exists
# Skipping station 08001 - data already exists
# Skipping station 08002 - data already exists
# Skipping station 08008 - data already exists
# Skipping station 08011 - data already exists
# Skipping station 08014 - data already exists
# Skipping station 08015 - data already exists
# Skipping station 08021 - data already exists
# Skipping station 08023 - data already exists
# Skipping station 08025 - data already exists
# Skipping station 08027 - data already exists
# Skipping station 08029 - data already exists
# Skipping station 08042 - data already exists
# Skipping station 08044 - data already exists
# Skipping station 08045 - data already exists
# Skipping station 08048 - data already exists
# Skipping station 08053 - data already exists
# Skipping station 08055 - data already exists
# Skipping station 08075 - data already exists
# Skipping station 08080 - data already exists
# Skipping station 08084 - data already exists
# Skipping station 08130 - data already exists
# Skipping station 08140 - data already exists
# Skipping station 08141 - data already exists
# Skipping station 08148 - data already exists
# Skipping station 08160 - data already exists
# Skipping station 08171 - data already exists
# Skipping station 08175 - data already exists
# Skipping station 08181 - data already exists
# Skipping station 08184 - data already exists
# Skipping station 08202 - data already exists
# Skipping station 08210 - data already exists
# Skipping station 08213 - data already exists
# Skipping station 08215 - data already exists
# Skipping station 08219 - data already exists
# Skipping station 08221 - data already exists
# Skipping station 08222 - data already exists
# Skipping station 08223 - data already exists
# Skipping station 08224 - data already exists
# Skipping station 08226 - data already exists
# Skipping station 08227 - data already exists
# Skipping station 08231 - data already exists
# Skipping station 08233 - data already exists
# Skipping station 08235 - data already exists
# Skipping station 08238 - data already exists
# Skipping station 08261 - data already exists
# Skipping station 08272 - data already exists
# Skipping station 08280 - data already exists
# Skipping station 08284 - data already exists
# Skipping station 08285 - data already exists
# Skipping station 08286 - data already exists
# Skipping station 08306 - data already exists
# Skipping station 08314 - data already exists
# Skipping station 08330 - data already exists
# Skipping station 08348 - data already exists
# Skipping station 08359 - data already exists
# Skipping station 08360 - data already exists
# Skipping station 08373 - data already exists
# Skipping station 08383 - data already exists
# Skipping station 08391 - data already exists
# Skipping station 08397 - data already exists
# Skipping station 08410 - data already exists
# Skipping station 08417 - data already exists
# Skipping station 08419 - data already exists
# Skipping station 08420 - data already exists
# Skipping station 08429 - data already exists
# Skipping station 08430 - data already exists
# Skipping station 08433 - data already exists
# Skipping station 08449 - data already exists
# Skipping station 08451 - data already exists
# Skipping station 08452 - data already exists
# Skipping station 08482 - data already exists
# Skipping station 08487 - data already exists
# Skipping station 08501 - data already exists
# Skipping station 08505 - data already exists
# Skipping station 08506 - data already exists
# Skipping station 08509 - data already exists
# Skipping station 08512 - data already exists
# Skipping station 08515 - data already exists
# Skipping station 08521 - data already exists
# Skipping station 08522 - data already exists
# Skipping station 08524 - data already exists
# Skipping station 08535 - data already exists
# Skipping station 08536 - data already exists
# Skipping station 08545 - data already exists
# Skipping station 08546 - data already exists
# Skipping station 08548 - data already exists
# Skipping station 08549 - data already exists
# Skipping station 08554 - data already exists
# Skipping station 08558 - data already exists
# Skipping station 08562 - data already exists
# Skipping station 08567 - data already exists
# Skipping station 08570 - data already exists
# Skipping station 08575 - data already exists
# Skipping station 10004 - data already exists
# Skipping station 10007 - data already exists
# Skipping station 10015 - data already exists
# Skipping station 10018 - data already exists
# Skipping station 10020 - data already exists
# Skipping station 10022 - data already exists
# Skipping station 10026 - data already exists
# Skipping station 10028 - data already exists
# Skipping station 10033 - data already exists
# Skipping station 10034 - data already exists
# Skipping station 10035 - data already exists
# Skipping station 10037 - data already exists
# Skipping station 10038 - data already exists
# Skipping station 10042 - data already exists
# Skipping station 10043 - data already exists
# Skipping station 10044 - data already exists
# Processed 1550 stations
# Skipping station 10046 - data already exists
# Skipping station 10055 - data already exists
# Skipping station 10091 - data already exists
# Skipping station 10093 - data already exists
# Skipping station 10097 - data already exists
# Skipping station 10113 - data already exists
# Skipping station 10122 - data already exists
# Skipping station 10124 - data already exists
# Skipping station 10126 - data already exists
# Skipping station 10129 - data already exists
# Skipping station 10130 - data already exists
# Skipping station 10131 - data already exists
# Skipping station 10136 - data already exists
# Skipping station 10139 - data already exists
# Skipping station 10142 - data already exists
# Skipping station 10146 - data already exists
# Processed 1600 stations
# Processed 1650 stations
# Processed 1700 stations
# Processed 1750 stations
# Processed 1800 stations
# Processed 1850 stations
# Processed 1900 stations
# Processed 1950 stations
# Processed 2000 stations
# Processed 2050 stations
# Processed 2100 stations
# Processed 2150 stations
# Processed 2200 stations
# Processed 2250 stations
# Processed 2300 stations
# Processed 2350 stations
# Processed 2400 stations
# Processed 2450 stations
# Processed 2500 stations
# Processed 2550 stations
# Processed 2600 stations
# Processed 2650 stations
# Processed 2700 stations
# Processed 2750 stations
# Processed 2800 stations
# Processed 2850 stations
# Processed 2900 stations
# Processed 2950 stations
# Processed 3000 stations
# Processed 3050 stations
# Processed 3100 stations
# Processed 3150 stations
# Processed 3200 stations
# Processed 3250 stations
# Processed 3300 stations
# Processed 3350 stations
# Processed 3400 stations
# Processed 3450 stations
# Processed 3500 stations
# Processed 3550 stations
# Processed 3600 stations
# Processed 3650 stations
# Processed 3700 stations
# Processed 3750 stations
# Processed 3800 stations
# Completed processing European stations

# %%
ru_stations = session.query(Station).filter(Station.country == 'RU').all()

for station in tqdm(ru_stations):
    city = get_nearest_city(station.latitude, station.longitude)
    if city:
        station.city = city
session.commit()
# Out:
#   0%|          | 0/1181 [00:00<?, ?it/s]
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# Диксон
# None
# Хатанга
# Сёяха
# None
# None
# None
# None
# None
# None
# None
# Саскылах
# городское поселение Тикси
# Жилинда
# None
# None
# Чокурдах
# None
# None
# None
# Североморск
# Териберка
# None
# None
# Верхнетуломский
# Мурманск
# None
# Ловозеро
# Островной
# None
# Ковдор
# None
# None
# None
# Краснощелье
# None
# None
# None
# None
# None
# None
# Умба
# None
# None
# None
# Нижняя Пёша
# Калевала
# None
# None
# None
# None
# Мезень
# None
# Юшкозеро
# Ругозеро
# None
# None
# None
# Колежма
# None
# None
# None
# Холмогоры
# Пинега
# Лешуконское
# Койнас
# Реболы
# None
# Сегежа
# Онега
# None
# None
# Сура
# Солнечный
# Ыджыдъяг
# Вяртсиля
# Медвежьегорск
# None
# Кондопога
# None
# Шенкурск
# Верхняя Тойма
# Яренск
# Сортавала
# Пряжа
# Петрозаводск
# Пудож
# Вытегра
# Каргополь
# Няндома
# Хорошевская
# Котлас
# Выборг
# Токсово
# Олонец
# Лодейное Поле
# Свирица
# Новая Ладога
# Винницы
# Белозерск
# Вожега
# Великий Устюг
# None
# сельское поселение Амдерма
# None
# None
# Дудинка
# None
# Мыс Каменный
# Нарьян-Мар
# None
# None
# None
# Воркута
# None
# Тазовский
# Игарка
# Окунев Нос
# Петрунь
# Салехард
# None
# None
# None
# None
# None
# None
# Печора
# None
# None
# None
# None
# None
# None
# None
# None
# Тутончаны
# Ухта
# Сосьва
# Берёзово
# Халясавэй
# None
# None
# None
# Троицко-Печорск
# Няксимволь
# Октябрьское
# Усть-Кулом
# Трехозёрка
# None
# None
# Сургут
# Ларьяк
# Бор
# None
# Кажым
# Гайны
# Серёгово
# Ивдель
# Чантырья
# Ханты-Мансийск
# None
# Александровское
# None
# None
# Сым
# None
# None
# Ярцево
# None
# None
# Оленёк
# None
# None
# None
# Верхоянск
# None
# None
# None
# Хонуу
# None
# Тура
# None
# None
# None
# None
# Нюрба
# None
# None
# None
# None
# Сегян-Кюёль
# None
# None
# None
# None
# None
# None
# None
# None
# Сунтар
# Крест-Хальджай
# None
# Сусуман
# Стрелка-Чуня
# Ербогачён
# Покровск
# None
# Ванавара
# None
# Ленск
# None
# Олёкминск
# Исит
# Якутск
# Амга
# None
# None
# None
# Арка
# None
# None
# None
# None
# Островное
# None
# None
# Илирней
# None
# None
# None
# Амгуэма
# None
# None
# Уэлен
# Зырянка
# Омолон
# None
# None
# Марково
# None
# Провидения
# None
# None
# Беринговский
# Сеймчан
# None
# Омсукчан
# Каменское
# None
# None
# None
# None
# None
# Магадан
# None
# None
# None
# None
# None
# Кингисепп
# Санкт-Петербург
# Белогорка
# Шлиссельбургское городское поселение
# Любань
# None
# Тихвин
# None
# Гдов
# Ретюнь
# городской округ Великий Новгород
# Хвойная
# городской округ Псков
# Дно
# Дубовицы
# Ямская Слобода
# Валдай
# None
# Бологое
# городское поселение Пушкиногорье
# Холм
# Демянск
# Осташков
# Вышний Волочёк
# Великие Луки
# городской округ Псков
# Торопец
# Ржев
# Кореничено
# Белый
# Вязьма-Брянская
# Калининград
# городской округ Смоленск
# Спас-Деменск
# Рославль
# Жуковка
# Брянск
# Красная Гора
# Трубчевск
# Бабаево
# Семенково-2
# None
# Никольск
# Опарино
# None
# Охона
# Ботово
# Кологрив
# Киров
# Максатиха
# Бежецк
# городской округ Рыбинск
# Буй
# Галич
# Николо-Полома
# Шарья
# Ветлуга
# Ленинское
# Котельнич
# Кумёны
# Кашин
# Углич
# городское поселение Ростов
# None
# Коряково
# Кинешма
# Коляново
# Юрьевец
# Красные Баки
# Шахунья
# Нолинское городское поселение
# None
# Кимры
# None
# городское поселение Александров
# Шуя
# None
# Нижний Новгород
# Козьмодемьянск
# None
# Новый Торъял
# Волоколамск
# Гагарин
# Можайск
# Лучинское
# Павловский Посад
# Владимир
# Гусь-Хрустальный
# Дмитриевская Слобода
# Сергач
# Чебоксары
# Канаш
# None
# Малоярославец
# None
# Наро-Фоминск
# Москва
# Серпухов
# Радужный
# Кашира
# Выкса
# Елатьма
# None
# Лукоянов
# Порецкое
# Восход
# Тетюши
# Калуга
# городское поселение Сухиничи
# Тула
# Михайлов
# городской округ Рязань
# Пионерская Роща
# Темниковское городское поселение
# Торбеево
# Куликовка
# Сурское
# Ульяновск
# Димитровград
# Нижняя Зароща
# Узловая
# Павелец
# Ряжск
# Моршанск
# Земетчино
# Пачелма
# Троицкое
# Новодевичье
# городской округ Орёл
# Ефремов
# Елец
# None
# городской округ Мичуринск
# Крутые Выселки
# Голынщина
# городской округ Пенза
# Сызрань
# Безенчук
# None
# Соликамск
# None
# Карпинск
# Серов
# Гари
# None
# Демьянское
# Кудымкар
# None
# Бисер
# Верхотурье
# Фалёнки
# Глазов
# Верещагино
# Пермь
# Пермь
# Лысьва
# None
# Нижний Тагил
# Алапаевск
# Туринск
# Тавда
# Тобольск
# Уржум
# Ножовка
# Оханск
# Мериново
# Шамары
# Артёмовский
# Тугулым
# Тюмень
# Усть-Ишим
# Тевриз
# Можга
# None
# Северный
# None
# Ашша
# Приданниково
# None
# Каменск-Уральский
# Камышлов
# Бутка
# Шатрово
# городской округ Ялуторовск
# Викулово
# None
# Тара
# None
# None
# Елабуга
# Мензелинск
# Аскино
# Нязепетровск
# Дуван
# None
# Шадринск
# None
# Ишим
# Тюкалинск
# Называевск
# Большеречье
# Саргатское
# None
# Муслюмово
# Бакалы
# Бирск
# Кушнаренково
# Улу-Теляк
# Златоуст
# Кропачёво
# Челябинск
# Шумиха
# Куртамыш
# Курган
# None
# None
# Исилькуль
# Калачинск
# Омск
# Чулпаново
# Челно-Вершины
# Раевский
# Подлесный
# Надеждино
# Уфа
# Мирный
# Троицк
# Звериноголовское
# Возвышен ауылдық округі
# Полтавка
# Одесское
# Черлак
# Красное Поселение
# None
# Тукан
# None
# Железнодорожный
# None
# Магнитогорск
# Саумалкөл
# Кішкенекөл
# Русская Поляна
# Самара
# Авангард
# Бузулук
# Шарлык
# None
# Карталы
# Тобыл
# None
# None
# None
# Средний Васюган
# None
# Парабель
# None
# Колпашево
# None
# Енисейск
# Стрелка
# Богучаны
# None
# None
# None
# Первомайское
# Пировское
# None
# None
# None
# Северное
# Томск
# Тюхтет
# None
# Ачинск
# Большая Мурта
# Сухобузимское
# None
# None
# Крещенское
# None
# Болотное
# Тайга
# Мариинск
# None
# Тисуль
# None
# None
# Красноярск
# Емельяново
# Уяр
# Канск
# Ирбейское
# Тайшет
# None
# Татарск
# Барабинск
# None
# Чулым
# None
# Колывань
# Мошково
# городской округ Новосибирск
# Тогучин
# Элитный
# None
# Новостройка
# Крапивинский
# Ужур
# Центральный
# Балахта
# None
# None
# Агинское
# Нижнеудинск
# Купино
# Здвинск
# None
# Чернаково
# None
# Маслянино
# None
# None
# None
# Идринское
# Верхняя Гутара
# None
# None
# Хабары
# Камень-на-Оби
# Баево
# Тальменка
# None
# None
# Тогул
# Кузедеево
# None
# Зелёное
# None
# Калинино
# Минусинск
# Ермаковское
# None
# Алыгджер
# Славгород
# Ребриха
# Солнечный
# Зональное
# None
# None
# Бея
# None
# Орлик
# None
# Витим
# None
# None
# None
# None
# None
# Мама
# None
# None
# Киренск
# Мамакан
# Бодайбо
# Братск
# None
# None
# Казачинское
# None
# Чара
# None
# None
# Тангуй
# None
# None
# Карам
# None
# None
# None
# None
# None
# None
# None
# None
# 4 отделение Государственной селекционной станции
# Икей
# Усть-Удинское сельское поселение
# Жигалово
# None
# None
# None
# None
# Багдарин
# None
# Усть-Каренга
# None
# Зима
# None
# Балаганск
# Бохан
# Качугское городское поселение
# None
# None
# Усть-Баргузин
# Баргузин
# None
# Тунгокочен
# Аксёново-Зиловское
# Могоча
# Ксеньевка
# None
# Амазар
# Ерофей Павлович
# None
# None
# None
# 兴安镇
# None
# None
# Иркутск
# Усть-Ордынский
# Ангарск
# Сухая
# Большое Голоустное
# Кабанск
# Горячинск
# Хоринск
# None
# Сосново-Озёрское
# Чита
# None
# None
# Чернышевск
# None
# Усть-Карск
# Сретенск
# None
# Монды
# Тунка
# None
# Бабушкин
# Улан-Удэ
# None
# None
# Петровск-Забайкальский
# Могзон
# Хилок
# Улёты
# Карымское
# None
# Агинское
# Шилка
# Шелопугино
# Нерчинский Завод
# None
# Кяхта
# Бичура
# Красный Чикой
# None
# None
# Кыра
# None
# Акша
# Оловянная
# Борзя
# Александровский Завод
# Доно
# Улан
# None
# городское поселение Алдан
# Томмот
# Чагда
# None
# None
# None
# None
# None
# None
# None
# Нелькан
# None
# None
# None
# None
# None
# None
# Удское
# Чумикан
# Магдагачи
# Тыгда
# None
# None
# None
# None
# None
# None
# None
# Николаевск-на-Амуре
# Черняево
# Октябрьский
# None
# None
# Стойба
# None
# имени Полины Осипенко
# None
# None
# None
# сельское поселение Село Богородское
# Шимановск
# Мазаново
# None
# None
# Средний Ургал
# None
# None
# None
# Амгунь
# None
# Благовещенск
# Белогорск
# None
# Завитинск
# Чекунда
# None
# None
# Комсомольск-на-Амуре
# Нижнетамбовское
# None
# None
# Поярково
# Архара
# None
# None
# None
# None
# Троицкое
# None
# None
# Екатерино-Никольское
# Ленинское
# Птичник
# None
# None
# Хабаровск
# None
# Советская Гавань
# Садовое
# Лермонтовка
# Гвасюги
# Агзу
# None
# Бикин
# None
# Светлая
# None
# None
# None
# None
# None
# None
# Пограничный
# Полтавка
# Астраханка
# Хороль
# Спасск-Дальний
# Свиягино
# Чугуевка
# Рудная Пристань
# Владивосток
# None
# Посьет
# Владивосток
# Анучино
# None
# Преображение
# None
# None
# None
# None
# Александровск-Сахалинский
# None
# None
# None
# None
# Углегорск
# Поронайск
# None
# Ильинское
# Холмск
# Долинск
# None
# None
# Южно-Сахалинск
# None
# Южно-Курильск
# Рейдово
# None
# None
# None
# None
# None
# None
# None
# Ключи
# None
# Долиновка
# None
# None
# Светлый
# Кавалерское
# Октябрьский
# Петропавловск-Камчатский
# None
# Никольское
# Поныри
# городской округ Курск
# городской округ Ливны
# Жердевка
# Ртищево
# Петровск
# None
# Свободный
# Хвалынск
# Пугачёв
# Пригородный
# None
# Старый Оскол
# Воронеж
# Воронеж
# None
# Борисоглебск
# Балашов
# Октябрьский Городок
# Саратов
# None
# Озинки
# Пролетарский
# Белгород
# Лиски
# Анна
# Урюпинск
# Заброды
# Елань
# Новоаннинский
# None
# Даниловка
# Красный Кут
# Валуйки
# Богучар
# Казанская
# None
# Серафимович
# Камышин
# городское поселение Палласовка
# Васильки
# Чертково
# Миллерово
# Боковская
# Эльтон
# городской округ Каменск-Шахтинский
# None
# None
# Волгоград
# Чёрный Яр
# Верхний Баскунчак
# Орда ауылдық округі
# Шахты
# Константиновск
# None
# Котельниково
# None
# Таганрог
# None
# Ростов-на-Дону
# Ростов-на-Дону
# Кущёвская
# Гигант
# Зимовники
# Новая Целина
# Заветное
# Ремонтное
# None
# Приморско-Ахтарск
# Каневская
# Тихорецк
# Городовиковск
# Дивное
# None
# Яшкуль
# Осыпной Бугор
# None
# Темрюк
# Тимашёвск
# Славянск-на-Кубани
# Краснодар
# Краснодар
# Кропоткин
# None
# Светлоград
# Благодарный
# None
# Лагань
# None
# Большая Глушица
# Перелюб
# Сорочинск
# Новосергиевка
# None
# None
# Бреды
# Забеловка
# None
# None
# None
# Акбулак
# None
# Аралколь
# Жаңақима
# Ерейментау
# Мартук
# Байтак
# Тұмабұлақ
# None
# Арқалық Қ.Ә.
# Арқалық Қ.Ә.
# Кертинди
# None
# None
# None
# Қызылқоға ауылдық округі
# Сағыз ауылдық округі
# Ырғыз
# None
# Кызылжар
# Жаңаарқа
# Махамбет ауылдық округі
# None
# None
# Қаражал Қ.Ә.
# Қосшағыл ауылдық округі
# None
# None
# None
# None
# None
# None
# None
# None
# None
# Родино
# Волчиха
# Рубцовск
# Змеиногорск
# Солонешное
# None
# None
# Артыбаш
# Кызыл
# None
# Баянаул
# Шемонаиха
# Усть-Кокса
# Онгудай
# Кош-Агач
# Мугур-Аксы
# Морен
# Қарқаралы
# Қараөлең ауылдық округі
# Өскемен
# Катонқарағай
# None
# None
# Малкелді ауылдық округі
# Қараауыл ауылдық округі
# None
# Аягөз қалалық әкімдігі
# None
# Талдықорған Қ.Ә.
# None
# Аққайнар
# Балыкчы
# Чолпон-Ата
# None
# Даркан
# Ак-Шийрак
# Геленджик
# Джубга
# Горячий Ключ
# Горный
# Туапсе
# Майкоп
# Армавир
# Невинномысск
# Пятигорск
# None
# Георгиевск
# Будённовск
# Кочубей
# None
# Сочи
# Красная Поляна
# None
# Моздок
# Кизляр
# None
# Рапыца
# Гәдоуҭа
# Теберда
# მესტია
# сельское поселение Шалушка
# Владикавказ
# Грозный
# Рьап ақыҭа ахадара
# ზუგდიდი
# ბაბილი
# ზედა ლუხვანო
# ამბროლაური
# None
# None
# Ботлих
# ფოთი
# ჭალა
# ორპირი
# საჩხერე
# მღვიმევი
# ყიფიანთუბანი
# Ленингор
# ახმეტა
# Хиндах
# Дербент
# Буйнакск
# None
# წიფნარი
# ჭარნალი
# საღრძე
# ახალციხე
# პატარა ზანავი
# ფონა
# ასპინძა
# ბორჯომი
# None
# ტაბაწყური
# წალკა
# თეთრიწყარო
# გურჯაანი
# None
# Касумкент
# ახალქალაქი
# None
# Ахты
# Ստեփանավան
# Ապարան
# Սևան
# Չարենցավան
# Մարտունի
# Մեծ Մասրիկ
# Արտաշատ
# Lerik
# Тұщықұдық
# None
# None
# None
# None
# None
# None
# Ойық
# Беловодское
# None
# None
# None
# None
# Зоосун
# Деҳманора
# Сары-Таш
# None
# Чашмаи кози
# نوسی
# None
# Благовещенск
# Бесовец
# None
# None
# Обь
# Омск
# Аэропорт
# None
# None
# None
# None
# Астрахань
# Челябинск
# None
# городской округ Нижневартовск
# Большое Савино
# Тюмень
# Новое
# None
# None
# Химки
# район Щербинка
# Курск
# None
# Нижний Новгород
# None
# Чебоксары
# Баратаевка
# None
# None
# None
